# %%
#PYTHON
import h5py
import numpy as np
import os
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pyspark

#SPARK
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession, SQLContext
from pyspark.sql.types import *
from pyspark.sql import Row
from pyspark.sql.functions import *
from operator import add

import sys

# Append the path to Pydoop to sys.path
#sys.path.append("/usr/local/lib/python3.8/dist-packages")

# %% [markdown]
# Spark Configuration

# %%
# Spark Session - 2 CORE - imporvement CONFIGURATION!!
# spark_session = SparkSession.builder\
#     .master("local[2]")\
#     .appName("pseudo_spark_nora")\
#     .getOrCreate()

# Set Hadoop configuration directory
#os.environ['HADOOP_CONF_DIR'] = '/path/to/hadoop/conf'
#spark_session.stop()
#os.environ['HDF5_USE_FILE_LOCKING'] = 'FALSE'

spark_session = SparkSession.builder \
    .appName("HDFS_Connection_Test_nora") \
    .master("yarn") \
    .config("spark.executor.instances", "2") \
    .getOrCreate()

# num executors 
# executor memory RAM 


# spark_session = SparkSession.builder \
#     .appName("HDFS_Connection_Test_nora") \
#     .master("yarn") \
#     .config("spark.executor.instances", "2") \
#     .config("spark.hadoop.fs.default.name", "hdfs://master-node:9000") \
#     .config("spark.hadoop.fs.defaultFS", "hdfs://master-node:9000") \
#     .config("spark.hadoop.fs.hdfs.impl", "org.apache.hadoop.hdfs.DistributedFileSystem") \
#     .config("spark.hadoop.dfs.server.namenode.class", "org.apache.hadoop.hdfs.server.namenode.NameNode") \
#     .config("spark.hadoop.conf", "org.apache.hadoop.hdfs.HdfsConfiguration") \
#     .getOrCreate()

#.config("spark.dynamicAllocation.enabled", False)\
#.config("spark.cores.max", 4)\


#.config("spark.jars.packages", "LLNL:spark-hdf5:0.0.4") \
# RDD API
spark_context = spark_session.sparkContext
spark_context.setLogLevel("INFO")

sqlContext = SQLContext(spark_session.sparkContext)
# Out:
# /home/hadoop/.local/lib/python3.8/site-packages/pyspark/sql/context.py:113: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %% [markdown]
# File Path

# %%
#file_roots = ['hdfs://130.238.29.183:9000//input/millionsongsubset.tar.gz']
directory_path = "file://data/B/A/A"
#directory_path = "data_AZ"
#Path300
#directory_path = "/user/hadoop/MillionSongSubset/A/A/"
#directory_path = "MillionSongSubset/A/A"
path = 'hdfs://master-node:9000/user/hadoop/MillionSongSubset_ASCI_analysis_songs/TRAAAAW128F429D538_songs.asci'
directory_path = "hdfs://master-node:9000/user/hadoop/MillionSongSubset_ASCI_analysis_songs"
# Out:
# 24/03/14 23:02:43 INFO YarnSchedulerBackend$YarnDriverEndpoint: Registered executor NettyRpcEndpointRef(spark-client://Executor) (192.168.2.40:44814) with ID 2,  ResourceProfileId 0
# 24/03/14 23:02:44 INFO BlockManagerMasterEndpoint: Registering block manager worker-node-2:35017 with 366.3 MiB RAM, BlockManagerId(2, worker-node-2, 35017, None)
# 24/03/14 23:02:46 INFO YarnSchedulerBackend$YarnDriverEndpoint: Registered executor NettyRpcEndpointRef(spark-client://Executor) (192.168.2.124:60916) with ID 1,  ResourceProfileId 0

# %%
rdd = spark_context.textFile(path)

# %%
for line in rdd.take(10):
    print(line)

# %%
content = rdd.map(lambda line: line.replace('\n', '').replace(' ', '').replace(',', '')).collect()

# %%
data = content[4:9]

# %%
rows = [Row(column1=data[5], column2=data[6], column3=data[25], column4=data[28], column5=data[29]) for data in [content]]

# Create DataFrame schema
schema = sqlContext.createDataFrame(rows)

# Register the DataFrame as a table
schema.registerTempTable("data_table")

# You can now perform SQL operations on the data
result = sqlContext.sql("SELECT * FROM data_table")

# Show the result
result.show()

# %%
#cleaned_rdd = rdd.map(lambda line: line.strip().replace('{', '').replace('}', '').split(','))
cleaned_rdd = rdd.map(lambda line: [value.strip('"').strip() for value in line.strip().replace('{', '').replace('}', '').split(',')])

# %%
for line in cleaned_rdd.take(5):
    print(line)

# %%
df = cleaned_rdd.toDF()

# %%
df.show()

# %%
from pyspark.ml.feature import Tokenizer

# %%
rdd = spark_context.textFile(path)

# Wende den Tokenizer auf jede Zeile an
tokenizer = Tokenizer(inputCol="value", outputCol="words")
tokenized_rdd = tokenizer.transform(rdd.map(lambda line: (line, )))

# Zeige die ersten 10 Zeilen des tokenisierten RDDs an
for row in tokenized_rdd.take(10):
    print(row.words)

# %%
values = []

# Datei öffnen und Zeilen lesen
with open(path, 'r') as file:
    for line in file:
        # Entferne führende und abschließende Leerzeichen und Zeilenumbrüche
        line = line.strip()
        # Entferne die geschweiften Klammern
        line = line.replace('{', '').replace('}', '')
        # Teile die Zeile an Kommas und füge die Werte zur Liste hinzu
        values.extend(line.split(','))

# Erstelle eine Zeile mit den Werten, getrennt durch Kommas
csv_line = ','.join(values)

# Zeige die CSV-Zeile an
print(csv_line)

# %%
df.createOrReplaceTempView("my_table")

# %%
sqlContext.sql("SELECT * FROM my_table").show()

# %%
from pyspark.sql.types import StructType, StructField, StringType
columns = ["column_{}".format(i) for i in range(1, 31 + 1)]  # Hier musst du die Anzahl der Spalten angeben

# Erstelle ein StructType-Schema für den DataFrame
schema = StructType([StructField(col, StringType(), True) for col in columns])

# %%
# read the csv from hdfs
#df = sqlContext.read.csv(directory_path, header=False, delimiter=,, inferSchema=True).cache()
#df = sqlContext.read.csv("hdfs://master-node:9000/user/hadoop/MillionSongSubset_ASCI/", header=True, inferSchema=True).cache()
#path = 'hdfs://master-node:9000/user/hadoop/MillionSongSubset_ASCI_analysis_songs/TRAAAAW128F429D538_songs.asci'
path = 'hdfs://master-node:9000/user/hadoop/MillionSongSubset_ASCI_analysis_songs'
df = sqlContext.read.option("delimiter", ",").csv(path).cache()
df = sqlContext.read.csv(path).cache()

# %%
df.show()

# %%
from pyspark.sql.functions import input_file_name

df = (sqlContext.read.option("delimiter", ",").csv(path)
      .withColumn("filename", input_file_name())
      .cache())

df.show()

# Erstellen einer Spalte für jede Datei
#df_pivoted = df.groupBy().pivot("filename").agg({"_c0": "first"})

# %%
df_pivoted.show()

# %%
df = df.select(split(df["_c0"], ",").alias("columns"))

# %%
df.show()

# %%
from pyspark.sql.functions import split, regexp_replace

# Read the text file as RDD
rdd = spark_context.textFile(directory_path)

# Remove braces {} and split the lines by comma
rdd = rdd.map(lambda line: line.strip('{}').split(','))

# Convert RDD to DataFrame
df = rdd.toDF()

# Rename columns
num_columns = len(df.columns)
columns = ["column_{}".format(i) for i in range(1, num_columns + 1)]
df = df.toDF(*columns)

# Cache the DataFrame
df.cache()

# Show DataFrame
df.show()

# %%
rdd = rdd.map(lambda line: line.strip('{}').split(','))

# %%
# Convert each element of the RDD to a string
rdd = rdd.map(lambda row: [str(elem) for elem in row])

# %%
# Collect a sample of the RDD and print it
sample = rdd.take(5)  # Take 5 records as a sample
for row in sample:
    print(row)

# %%
df = rdd.toDF()

# %%
df.createOrReplaceTempView("my_table")

# %%
sqlContext.sql("SELECT * FROM my_table").show()

# %%
df.cache()

# %%
df.show()

# %%
df.printSchema()

# %%
df = pd.read_csv(directory_path + 'TRAAAAW128F429D538.asci', delimiter='\t')

# %%
# # Use Spark to list files in HDFS directory
# hdfs_files = spark_session._jvm.org.apache.hadoop.fs.FileSystem.get(spark._jsc.hadoopConfiguration()) \
#     .listStatus(spark_session._jvm.org.apache.hadoop.fs.Path(directory_path))
#path = 'hdfs://master-node:9000/user/hadoop/MillionSongSubset_ASCI_analysis_songs/TRAAAAW128F429D538_songs.asci'
path = 'hdfs://master-node:9000/user/hadoop/MSD_ASCI/'
# Out:
# 24/03/14 23:02:46 INFO BlockManagerMasterEndpoint: Registering block manager worker-node-1:37441 with 366.3 MiB RAM, BlockManagerId(1, worker-node-1, 37441, None)

# %% [markdown]
# # 1) Saving the paths to the HDF5 files

# %%
def get_h5_file_paths_hdfs(spark, hdfs_directory_path):
    h5_file_paths = []

    # Use Spark to list files in HDFS directory
    hdfs_files = spark._jvm.org.apache.hadoop.fs.FileSystem.get(spark._jsc.hadoopConfiguration()) \
        .listStatus(spark._jvm.org.apache.hadoop.fs.Path(hdfs_directory_path))

    # Extract file paths from HDFS file status
    for hdfs_file_status in hdfs_files:
        file_path = hdfs_file_status.getPath().toString()

        if hdfs_file_status.isDirectory():
            # If it's a directory, recursively gather paths
            h5_file_paths.extend(get_h5_file_paths_hdfs(spark, file_path))
        elif file_path.endswith(".asci"):
            # If it's an HDF5 file, add to the list
            h5_file_paths.append(file_path)

    return h5_file_paths

# %%
h5_file_paths = get_h5_file_paths_hdfs(spark_session, path)

print('{} HDF5 file paths gathered (HDFS)'.format(len(h5_file_paths)))
for file_path in h5_file_paths[:50]:
    print(file_path)

# %% [markdown]
# # 2) List h5_file_paths is converted to RDD

# %%
h5_file_paths[:30]

# %%
file_paths = spark_context.parallelize(h5_file_paths)
file_paths

# %%
file_first = file_paths.first()
file_first

# %%
#file_paths = spark_context.wholeTextFiles(path).map(lambda x: x[0]).collect()
file_paths = spark_context.wholeTextFiles(path).map(lambda x: x[0]).take(200)
# Out:
# 24/03/14 23:14:18 INFO MemoryStore: Block broadcast_341 stored as values in memory (estimated size 344.0 KiB, free 360.4 MiB)
# 24/03/14 23:14:18 INFO MemoryStore: Block broadcast_341_piece0 stored as bytes in memory (estimated size 33.3 KiB, free 360.4 MiB)
# 24/03/14 23:14:18 INFO BlockManagerInfo: Added broadcast_341_piece0 in memory on master-node:44443 (size: 33.3 KiB, free: 365.8 MiB)
# 24/03/14 23:14:18 INFO SparkContext: Created broadcast 341 from wholeTextFiles at NativeMethodAccessorImpl.java:0
# 24/03/14 23:14:19 INFO BlockManagerInfo: Removed broadcast_338_piece0 on master-node:44443 in memory (size: 8.8 KiB, free: 365.8 MiB)
# 24/03/14 23:14:19 INFO BlockManagerInfo: Removed broadcast_338_piece0 on worker-node-1:37441 in memory (size: 8.8 KiB, free: 365.8 MiB)
# 24/03/14 23:14:19 INFO BlockManagerInfo: Removed broadcast_340_piece0 on master-node:44443 in memory (size: 10.4 KiB, free: 365.8 MiB)
# 24/03/14 23:14:19 INFO BlockManagerInfo: Removed broadcast_340_piece0 on worker-node-2:35017 in memory (size: 10.4 KiB, free: 365.8 MiB)
# 24/03/14 23:14:19 INFO BlockManagerInfo: Removed broadcast_337_piece0 on master-node:44443 in memory (size: 12.1 KiB, free: 365.8 MiB)
# 24/03/14 23:14:19 INFO BlockManagerInfo: Removed broadcast_337_piece0 on worker-node-2:35017 in memory (size: 12.1 KiB, free: 365.8 MiB)
# 24/03/14 23:14:19 INFO BlockManagerInfo: Removed broadcast_337_piece0 on worker-node-1:37441 in memory (size: 12.1 KiB, free: 365.8 MiB)
# 24/03/14 23:14:19 INFO BlockManagerInfo: Removed broadcast_339_piece0 on master-node:44443 in memory (size: 14.8 KiB, free: 365.8 MiB)
# 24/03/14 23:14:19 INFO BlockManagerInfo: Removed broadcast_339_piece0 on worker-node-1:37441 in memory (size: 14.8 KiB, free: 365.8 MiB)
# 24/03/14 23:14:19 INFO BlockManagerInfo: Removed broadcast_339_piece0 on worker-node-2:35017 in memory (size: 14.8 KiB, free: 365.8 MiB)
# 24/03/14 23:14:19 INFO BlockManagerInfo: Removed broadcast_336_piece0 on master-node:44443 in memory (size: 7.0 KiB, free: 365.8 MiB)
# 24/03/14 23:14:19 INFO BlockManagerInfo: Removed broadcast_336_piece0 on worker-node-2:35017 in memory (size: 7.0 KiB, free: 365.8 MiB)
# 24/03/14 23:14:19 INFO FileInputFormat: Total input files to process : 10000
# 24/03/14 23:14:20 INFO FileInputFormat: Total input files to process : 10000
# 24/03/14 23:14:20 INFO SparkContext: Starting job: runJob at PythonRDD.scala:181
# 24/03/14 23:14:20 INFO DAGScheduler: Got job 179 (runJob at PythonRDD.scala:181) with 1 output partitions
# 24/03/14 23:14:20 INFO DAGScheduler: Final stage: ResultStage 185 (runJob at PythonRDD.scala:181)
# 24/03/14 23:14:20 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:20 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:20 INFO DAGScheduler: Submitting ResultStage 185 (PythonRDD[548] at RDD at PythonRDD.scala:53), which has no missing parents
# 24/03/14 23:14:20 INFO MemoryStore: Block broadcast_342 stored as values in memory (estimated size 8.2 KiB, free 360.6 MiB)
# 24/03/14 23:14:20 INFO MemoryStore: Block broadcast_342_piece0 stored as bytes in memory (estimated size 5.0 KiB, free 360.6 MiB)
# 24/03/14 23:14:20 INFO BlockManagerInfo: Added broadcast_342_piece0 in memory on master-node:44443 (size: 5.0 KiB, free: 365.8 MiB)
# 24/03/14 23:14:20 INFO SparkContext: Created broadcast 342 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:20 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 185 (PythonRDD[548] at RDD at PythonRDD.scala:53) (first 15 tasks are for partitions Vector(0))
# 24/03/14 23:14:20 INFO YarnScheduler: Adding task set 185.0 with 1 tasks resource profile 0
# 24/03/14 23:14:20 INFO TaskSetManager: Starting task 0.0 in stage 185.0 (TID 346) (worker-node-2, executor 2, partition 0, NODE_LOCAL, 434776 bytes)
# 24/03/14 23:14:20 INFO BlockManagerInfo: Added broadcast_342_piece0 in memory on worker-node-2:35017 (size: 5.0 KiB, free: 365.8 MiB)
# 24/03/14 23:14:20 INFO BlockManagerInfo: Added broadcast_341_piece0 in memory on worker-node-2:35017 (size: 33.3 KiB, free: 365.8 MiB)
# 24/03/14 23:14:20 INFO TaskSetManager: Finished task 0.0 in stage 185.0 (TID 346) in 393 ms on worker-node-2 (executor 2) (1/1)
# 24/03/14 23:14:20 INFO YarnScheduler: Removed TaskSet 185.0, whose tasks have all completed, from pool
# 24/03/14 23:14:20 INFO DAGScheduler: ResultStage 185 (runJob at PythonRDD.scala:181) finished in 0.399 s
# 24/03/14 23:14:20 INFO DAGScheduler: Job 179 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:20 INFO YarnScheduler: Killing all running tasks in stage 185: Stage finished
# 24/03/14 23:14:20 INFO DAGScheduler: Job 179 finished: runJob at PythonRDD.scala:181, took 0.402314 s

# %%
all_rows = []

for file_path in file_paths:
    # Lese die Datei und bereinige den Inhalt
    rdd = spark_context.textFile(file_path)
    content = rdd.map(lambda line: line.replace('\n', '').replace(' ', '').replace(',', '')).collect()
    
    # Erstelle Zeilen für jede Datei
    rows = [Row(column1=data[5], column2=data[6], column3=data[28], column4=data[25], column5=data[23], column6=data[29], column7=data[30], column8=data[31]) for data in [content]]
    
    # Füge die Zeilen zur gemeinsamen Liste hinzu
    all_rows.extend(rows)
# Out:
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_343 stored as values in memory (estimated size 358.7 KiB, free 360.2 MiB)
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_343_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 360.2 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_343_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 365.8 MiB)
# 24/03/14 23:14:24 INFO SparkContext: Created broadcast 343 from textFile at <unknown>:0
# 24/03/14 23:14:24 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:24 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:24 INFO DAGScheduler: Got job 180 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:24 INFO DAGScheduler: Final stage: ResultStage 186 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:24 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:24 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:24 INFO DAGScheduler: Submitting ResultStage 186 (PythonRDD[551] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_344 stored as values in memory (estimated size 7.7 KiB, free 360.2 MiB)
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_344_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 360.2 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_344_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 365.8 MiB)
# 24/03/14 23:14:24 INFO SparkContext: Created broadcast 344 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:24 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 186 (PythonRDD[551] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:24 INFO YarnScheduler: Adding task set 186.0 with 2 tasks resource profile 0
# 24/03/14 23:14:24 INFO TaskSetManager: Starting task 0.0 in stage 186.0 (TID 347) (worker-node-1, executor 1, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:24 INFO TaskSetManager: Starting task 1.0 in stage 186.0 (TID 348) (worker-node-2, executor 2, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_344_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 365.8 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_344_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 365.8 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_343_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 365.8 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_343_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 365.8 MiB)
# 24/03/14 23:14:24 INFO TaskSetManager: Finished task 1.0 in stage 186.0 (TID 348) in 60 ms on worker-node-2 (executor 2) (1/2)
# 24/03/14 23:14:24 INFO TaskSetManager: Finished task 0.0 in stage 186.0 (TID 347) in 76 ms on worker-node-1 (executor 1) (2/2)
# 24/03/14 23:14:24 INFO YarnScheduler: Removed TaskSet 186.0, whose tasks have all completed, from pool
# 24/03/14 23:14:24 INFO DAGScheduler: ResultStage 186 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.084 s
# 24/03/14 23:14:24 INFO DAGScheduler: Job 180 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:24 INFO YarnScheduler: Killing all running tasks in stage 186: Stage finished
# 24/03/14 23:14:24 INFO DAGScheduler: Job 180 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.088880 s
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_345 stored as values in memory (estimated size 358.7 KiB, free 359.8 MiB)
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_345_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 359.8 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_345_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO SparkContext: Created broadcast 345 from textFile at <unknown>:0
# 24/03/14 23:14:24 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:24 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:24 INFO DAGScheduler: Got job 181 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:24 INFO DAGScheduler: Final stage: ResultStage 187 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:24 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:24 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:24 INFO DAGScheduler: Submitting ResultStage 187 (PythonRDD[554] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_346 stored as values in memory (estimated size 7.7 KiB, free 359.8 MiB)
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_346_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 359.8 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_346_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO SparkContext: Created broadcast 346 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:24 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 187 (PythonRDD[554] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:24 INFO YarnScheduler: Adding task set 187.0 with 2 tasks resource profile 0
# 24/03/14 23:14:24 INFO TaskSetManager: Starting task 0.0 in stage 187.0 (TID 349) (worker-node-2, executor 2, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:24 INFO TaskSetManager: Starting task 1.0 in stage 187.0 (TID 350) (worker-node-1, executor 1, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_346_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 365.8 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_346_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 365.8 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_345_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 365.8 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_345_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO TaskSetManager: Finished task 1.0 in stage 187.0 (TID 350) in 36 ms on worker-node-1 (executor 1) (1/2)
# 24/03/14 23:14:24 INFO TaskSetManager: Finished task 0.0 in stage 187.0 (TID 349) in 41 ms on worker-node-2 (executor 2) (2/2)
# 24/03/14 23:14:24 INFO YarnScheduler: Removed TaskSet 187.0, whose tasks have all completed, from pool
# 24/03/14 23:14:24 INFO DAGScheduler: ResultStage 187 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.046 s
# 24/03/14 23:14:24 INFO DAGScheduler: Job 181 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:24 INFO YarnScheduler: Killing all running tasks in stage 187: Stage finished
# 24/03/14 23:14:24 INFO DAGScheduler: Job 181 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.048337 s
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_347 stored as values in memory (estimated size 358.7 KiB, free 359.4 MiB)
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_347_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 359.4 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_347_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO SparkContext: Created broadcast 347 from textFile at <unknown>:0
# 24/03/14 23:14:24 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:24 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:24 INFO DAGScheduler: Got job 182 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:24 INFO DAGScheduler: Final stage: ResultStage 188 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:24 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:24 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:24 INFO DAGScheduler: Submitting ResultStage 188 (PythonRDD[557] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_348 stored as values in memory (estimated size 7.7 KiB, free 359.4 MiB)
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_348_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 359.4 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_348_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO SparkContext: Created broadcast 348 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:24 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 188 (PythonRDD[557] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:24 INFO YarnScheduler: Adding task set 188.0 with 2 tasks resource profile 0
# 24/03/14 23:14:24 INFO TaskSetManager: Starting task 0.0 in stage 188.0 (TID 351) (worker-node-2, executor 2, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:24 INFO TaskSetManager: Starting task 1.0 in stage 188.0 (TID 352) (worker-node-1, executor 1, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_348_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 365.8 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_348_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_347_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_347_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO TaskSetManager: Finished task 1.0 in stage 188.0 (TID 352) in 40 ms on worker-node-1 (executor 1) (1/2)
# 24/03/14 23:14:24 INFO TaskSetManager: Finished task 0.0 in stage 188.0 (TID 351) in 89 ms on worker-node-2 (executor 2) (2/2)
# 24/03/14 23:14:24 INFO YarnScheduler: Removed TaskSet 188.0, whose tasks have all completed, from pool
# 24/03/14 23:14:24 INFO DAGScheduler: ResultStage 188 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.096 s
# 24/03/14 23:14:24 INFO DAGScheduler: Job 182 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:24 INFO YarnScheduler: Killing all running tasks in stage 188: Stage finished
# 24/03/14 23:14:24 INFO DAGScheduler: Job 182 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.100778 s
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_349 stored as values in memory (estimated size 358.7 KiB, free 359.0 MiB)
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_349_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 359.0 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_349_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO SparkContext: Created broadcast 349 from textFile at <unknown>:0
# 24/03/14 23:14:24 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:24 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:24 INFO DAGScheduler: Got job 183 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:24 INFO DAGScheduler: Final stage: ResultStage 189 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:24 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:24 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:24 INFO DAGScheduler: Submitting ResultStage 189 (PythonRDD[560] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_350 stored as values in memory (estimated size 7.7 KiB, free 359.0 MiB)
# 24/03/14 23:14:24 INFO MemoryStore: Block broadcast_350_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 359.0 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_350_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO SparkContext: Created broadcast 350 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:24 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 189 (PythonRDD[560] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:24 INFO YarnScheduler: Adding task set 189.0 with 2 tasks resource profile 0
# 24/03/14 23:14:24 INFO TaskSetManager: Starting task 0.0 in stage 189.0 (TID 353) (worker-node-1, executor 1, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:24 INFO TaskSetManager: Starting task 1.0 in stage 189.0 (TID 354) (worker-node-2, executor 2, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_350_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_350_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_349_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO BlockManagerInfo: Added broadcast_349_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 365.7 MiB)
# 24/03/14 23:14:24 INFO TaskSetManager: Finished task 1.0 in stage 189.0 (TID 354) in 40 ms on worker-node-2 (executor 2) (1/2)
# 24/03/14 23:14:25 INFO TaskSetManager: Finished task 0.0 in stage 189.0 (TID 353) in 89 ms on worker-node-1 (executor 1) (2/2)
# 24/03/14 23:14:25 INFO YarnScheduler: Removed TaskSet 189.0, whose tasks have all completed, from pool
# 24/03/14 23:14:25 INFO DAGScheduler: ResultStage 189 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.095 s
# 24/03/14 23:14:25 INFO DAGScheduler: Job 183 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:25 INFO YarnScheduler: Killing all running tasks in stage 189: Stage finished
# 24/03/14 23:14:25 INFO DAGScheduler: Job 183 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.097374 s
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_351 stored as values in memory (estimated size 358.7 KiB, free 358.6 MiB)
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_351_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 358.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_351_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO SparkContext: Created broadcast 351 from textFile at <unknown>:0
# 24/03/14 23:14:25 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:25 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:25 INFO DAGScheduler: Got job 184 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:25 INFO DAGScheduler: Final stage: ResultStage 190 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:25 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Submitting ResultStage 190 (PythonRDD[563] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_352 stored as values in memory (estimated size 7.7 KiB, free 358.6 MiB)
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_352_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 358.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_352_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO SparkContext: Created broadcast 352 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:25 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 190 (PythonRDD[563] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:25 INFO YarnScheduler: Adding task set 190.0 with 2 tasks resource profile 0
# 24/03/14 23:14:25 INFO TaskSetManager: Starting task 0.0 in stage 190.0 (TID 355) (worker-node-1, executor 1, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:25 INFO TaskSetManager: Starting task 1.0 in stage 190.0 (TID 356) (worker-node-2, executor 2, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_352_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 365.7 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_352_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 365.7 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_351_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_351_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 365.7 MiB)
# 24/03/14 23:14:25 INFO TaskSetManager: Finished task 1.0 in stage 190.0 (TID 356) in 37 ms on worker-node-2 (executor 2) (1/2)
# 24/03/14 23:14:25 INFO TaskSetManager: Finished task 0.0 in stage 190.0 (TID 355) in 140 ms on worker-node-1 (executor 1) (2/2)
# 24/03/14 23:14:25 INFO YarnScheduler: Removed TaskSet 190.0, whose tasks have all completed, from pool
# 24/03/14 23:14:25 INFO DAGScheduler: ResultStage 190 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.147 s
# 24/03/14 23:14:25 INFO DAGScheduler: Job 184 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:25 INFO YarnScheduler: Killing all running tasks in stage 190: Stage finished
# 24/03/14 23:14:25 INFO DAGScheduler: Job 184 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.151329 s
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_353 stored as values in memory (estimated size 358.7 KiB, free 358.2 MiB)
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_353_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 358.2 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_353_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO SparkContext: Created broadcast 353 from textFile at <unknown>:0
# 24/03/14 23:14:25 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:25 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:25 INFO DAGScheduler: Got job 185 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:25 INFO DAGScheduler: Final stage: ResultStage 191 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:25 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Submitting ResultStage 191 (PythonRDD[566] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_354 stored as values in memory (estimated size 7.7 KiB, free 358.2 MiB)
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_354_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 358.2 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_354_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO SparkContext: Created broadcast 354 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:25 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 191 (PythonRDD[566] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:25 INFO YarnScheduler: Adding task set 191.0 with 2 tasks resource profile 0
# 24/03/14 23:14:25 INFO TaskSetManager: Starting task 0.0 in stage 191.0 (TID 357) (worker-node-2, executor 2, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:25 INFO TaskSetManager: Starting task 1.0 in stage 191.0 (TID 358) (worker-node-1, executor 1, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_354_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 365.7 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_354_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_353_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_353_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO TaskSetManager: Finished task 1.0 in stage 191.0 (TID 358) in 35 ms on worker-node-1 (executor 1) (1/2)
# 24/03/14 23:14:25 INFO TaskSetManager: Finished task 0.0 in stage 191.0 (TID 357) in 83 ms on worker-node-2 (executor 2) (2/2)
# 24/03/14 23:14:25 INFO YarnScheduler: Removed TaskSet 191.0, whose tasks have all completed, from pool
# 24/03/14 23:14:25 INFO DAGScheduler: ResultStage 191 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.088 s
# 24/03/14 23:14:25 INFO DAGScheduler: Job 185 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:25 INFO YarnScheduler: Killing all running tasks in stage 191: Stage finished
# 24/03/14 23:14:25 INFO DAGScheduler: Job 185 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.090061 s
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_355 stored as values in memory (estimated size 358.7 KiB, free 357.8 MiB)
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_355_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 357.8 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_355_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO SparkContext: Created broadcast 355 from textFile at <unknown>:0
# 24/03/14 23:14:25 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:25 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:25 INFO DAGScheduler: Got job 186 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:25 INFO DAGScheduler: Final stage: ResultStage 192 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:25 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Submitting ResultStage 192 (PythonRDD[569] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_356 stored as values in memory (estimated size 7.7 KiB, free 357.8 MiB)
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_356_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 357.8 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_356_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO SparkContext: Created broadcast 356 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:25 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 192 (PythonRDD[569] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:25 INFO YarnScheduler: Adding task set 192.0 with 2 tasks resource profile 0
# 24/03/14 23:14:25 INFO TaskSetManager: Starting task 0.0 in stage 192.0 (TID 359) (worker-node-1, executor 1, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:25 INFO TaskSetManager: Starting task 1.0 in stage 192.0 (TID 360) (worker-node-2, executor 2, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_344_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_344_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_344_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_350_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_356_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_350_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_350_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_356_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_355_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_355_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_348_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_348_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_348_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_342_piece0 on master-node:44443 in memory (size: 5.0 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_342_piece0 on worker-node-2:35017 in memory (size: 5.0 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_346_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_346_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_346_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO TaskSetManager: Finished task 1.0 in stage 192.0 (TID 360) in 35 ms on worker-node-2 (executor 2) (1/2)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_354_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_354_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_354_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_352_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_352_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Removed broadcast_352_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO TaskSetManager: Finished task 0.0 in stage 192.0 (TID 359) in 69 ms on worker-node-1 (executor 1) (2/2)
# 24/03/14 23:14:25 INFO YarnScheduler: Removed TaskSet 192.0, whose tasks have all completed, from pool
# 24/03/14 23:14:25 INFO DAGScheduler: ResultStage 192 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.074 s
# 24/03/14 23:14:25 INFO DAGScheduler: Job 186 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:25 INFO YarnScheduler: Killing all running tasks in stage 192: Stage finished
# 24/03/14 23:14:25 INFO DAGScheduler: Job 186 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.076700 s
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_357 stored as values in memory (estimated size 358.7 KiB, free 357.5 MiB)
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_357_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 357.5 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_357_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO SparkContext: Created broadcast 357 from textFile at <unknown>:0
# 24/03/14 23:14:25 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:25 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:25 INFO DAGScheduler: Got job 187 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:25 INFO DAGScheduler: Final stage: ResultStage 193 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:25 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Submitting ResultStage 193 (PythonRDD[572] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_358 stored as values in memory (estimated size 7.7 KiB, free 357.5 MiB)
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_358_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 357.5 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_358_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 365.5 MiB)
# 24/03/14 23:14:25 INFO SparkContext: Created broadcast 358 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:25 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 193 (PythonRDD[572] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:25 INFO YarnScheduler: Adding task set 193.0 with 2 tasks resource profile 0
# 24/03/14 23:14:25 INFO TaskSetManager: Starting task 0.0 in stage 193.0 (TID 361) (worker-node-1, executor 1, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:25 INFO TaskSetManager: Starting task 1.0 in stage 193.0 (TID 362) (worker-node-2, executor 2, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_358_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_358_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_357_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 365.5 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_357_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO TaskSetManager: Finished task 0.0 in stage 193.0 (TID 361) in 30 ms on worker-node-1 (executor 1) (1/2)
# 24/03/14 23:14:25 INFO TaskSetManager: Finished task 1.0 in stage 193.0 (TID 362) in 50 ms on worker-node-2 (executor 2) (2/2)
# 24/03/14 23:14:25 INFO YarnScheduler: Removed TaskSet 193.0, whose tasks have all completed, from pool
# 24/03/14 23:14:25 INFO DAGScheduler: ResultStage 193 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.058 s
# 24/03/14 23:14:25 INFO DAGScheduler: Job 187 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:25 INFO YarnScheduler: Killing all running tasks in stage 193: Stage finished
# 24/03/14 23:14:25 INFO DAGScheduler: Job 187 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.062477 s
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_359 stored as values in memory (estimated size 358.7 KiB, free 357.1 MiB)
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_359_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 357.1 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_359_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 365.5 MiB)
# 24/03/14 23:14:25 INFO SparkContext: Created broadcast 359 from textFile at <unknown>:0
# 24/03/14 23:14:25 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:25 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:25 INFO DAGScheduler: Got job 188 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:25 INFO DAGScheduler: Final stage: ResultStage 194 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:25 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Submitting ResultStage 194 (PythonRDD[575] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_360 stored as values in memory (estimated size 7.7 KiB, free 357.1 MiB)
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_360_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 357.1 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_360_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 365.5 MiB)
# 24/03/14 23:14:25 INFO SparkContext: Created broadcast 360 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:25 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 194 (PythonRDD[575] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:25 INFO YarnScheduler: Adding task set 194.0 with 2 tasks resource profile 0
# 24/03/14 23:14:25 INFO TaskSetManager: Starting task 0.0 in stage 194.0 (TID 363) (worker-node-1, executor 1, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:25 INFO TaskSetManager: Starting task 1.0 in stage 194.0 (TID 364) (worker-node-2, executor 2, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_360_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 365.6 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_360_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 365.5 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_359_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 365.5 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_359_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 365.5 MiB)
# 24/03/14 23:14:25 INFO TaskSetManager: Finished task 0.0 in stage 194.0 (TID 363) in 32 ms on worker-node-1 (executor 1) (1/2)
# 24/03/14 23:14:25 INFO TaskSetManager: Finished task 1.0 in stage 194.0 (TID 364) in 80 ms on worker-node-2 (executor 2) (2/2)
# 24/03/14 23:14:25 INFO YarnScheduler: Removed TaskSet 194.0, whose tasks have all completed, from pool
# 24/03/14 23:14:25 INFO DAGScheduler: ResultStage 194 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.086 s
# 24/03/14 23:14:25 INFO DAGScheduler: Job 188 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:25 INFO YarnScheduler: Killing all running tasks in stage 194: Stage finished
# 24/03/14 23:14:25 INFO DAGScheduler: Job 188 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.090211 s
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_361 stored as values in memory (estimated size 358.7 KiB, free 356.7 MiB)
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_361_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 356.7 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_361_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 365.5 MiB)
# 24/03/14 23:14:25 INFO SparkContext: Created broadcast 361 from textFile at <unknown>:0
# 24/03/14 23:14:25 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:25 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:25 INFO DAGScheduler: Got job 189 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:25 INFO DAGScheduler: Final stage: ResultStage 195 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:25 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Submitting ResultStage 195 (PythonRDD[578] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_362 stored as values in memory (estimated size 7.7 KiB, free 356.7 MiB)
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_362_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 356.7 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_362_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 365.5 MiB)
# 24/03/14 23:14:25 INFO SparkContext: Created broadcast 362 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:25 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 195 (PythonRDD[578] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:25 INFO YarnScheduler: Adding task set 195.0 with 2 tasks resource profile 0
# 24/03/14 23:14:25 INFO TaskSetManager: Starting task 0.0 in stage 195.0 (TID 365) (worker-node-1, executor 1, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:25 INFO TaskSetManager: Starting task 1.0 in stage 195.0 (TID 366) (worker-node-2, executor 2, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_362_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 365.5 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_362_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 365.5 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_361_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 365.5 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_361_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 365.5 MiB)
# 24/03/14 23:14:25 INFO TaskSetManager: Finished task 1.0 in stage 195.0 (TID 366) in 46 ms on worker-node-2 (executor 2) (1/2)
# 24/03/14 23:14:25 INFO TaskSetManager: Finished task 0.0 in stage 195.0 (TID 365) in 75 ms on worker-node-1 (executor 1) (2/2)
# 24/03/14 23:14:25 INFO YarnScheduler: Removed TaskSet 195.0, whose tasks have all completed, from pool
# 24/03/14 23:14:25 INFO DAGScheduler: ResultStage 195 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.084 s
# 24/03/14 23:14:25 INFO DAGScheduler: Job 189 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:25 INFO YarnScheduler: Killing all running tasks in stage 195: Stage finished
# 24/03/14 23:14:25 INFO DAGScheduler: Job 189 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.088512 s
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_363 stored as values in memory (estimated size 358.7 KiB, free 356.4 MiB)
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_363_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 356.3 MiB)
# 24/03/14 23:14:25 INFO BlockManagerInfo: Added broadcast_363_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 365.4 MiB)
# 24/03/14 23:14:25 INFO SparkContext: Created broadcast 363 from textFile at <unknown>:0
# 24/03/14 23:14:25 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:25 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:25 INFO DAGScheduler: Got job 190 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:25 INFO DAGScheduler: Final stage: ResultStage 196 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:25 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:25 INFO DAGScheduler: Submitting ResultStage 196 (PythonRDD[581] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:25 INFO MemoryStore: Block broadcast_364 stored as values in memory (estimated size 7.7 KiB, free 356.3 MiB)
# 24/03/14 23:14:26 INFO MemoryStore: Block broadcast_364_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 356.3 MiB)
# 24/03/14 23:14:26 INFO BlockManagerInfo: Added broadcast_364_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 365.4 MiB)
# 24/03/14 23:14:26 INFO SparkContext: Created broadcast 364 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:26 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 196 (PythonRDD[581] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:26 INFO YarnScheduler: Adding task set 196.0 with 2 tasks resource profile 0
# 24/03/14 23:14:26 INFO TaskSetManager: Starting task 0.0 in stage 196.0 (TID 367) (worker-node-1, executor 1, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:26 INFO TaskSetManager: Starting task 1.0 in stage 196.0 (TID 368) (worker-node-2, executor 2, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:26 INFO BlockManagerInfo: Added broadcast_364_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 365.5 MiB)
# 24/03/14 23:14:26 INFO BlockManagerInfo: Added broadcast_364_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 365.5 MiB)
# 24/03/14 23:14:26 INFO BlockManagerInfo: Added broadcast_363_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 365.5 MiB)
# 24/03/14 23:14:26 INFO BlockManagerInfo: Added broadcast_363_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 365.4 MiB)
# 24/03/14 23:14:26 INFO TaskSetManager: Finished task 0.0 in stage 196.0 (TID 367) in 29 ms on worker-node-1 (executor 1) (1/2)
# 24/03/14 23:14:26 INFO TaskSetManager: Finished task 1.0 in stage 196.0 (TID 368) in 33 ms on worker-node-2 (executor 2) (2/2)
# 24/03/14 23:14:26 INFO YarnScheduler: Removed TaskSet 196.0, whose tasks have all completed, from pool
# 24/03/14 23:14:26 INFO DAGScheduler: ResultStage 196 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.042 s
# 24/03/14 23:14:26 INFO DAGScheduler: Job 190 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:26 INFO YarnScheduler: Killing all running tasks in stage 196: Stage finished
# 24/03/14 23:14:26 INFO DAGScheduler: Job 190 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.045761 s
# 24/03/14 23:14:26 INFO MemoryStore: Block broadcast_365 stored as values in memory (estimated size 358.7 KiB, free 356.0 MiB)
# 24/03/14 23:14:26 INFO MemoryStore: Block broadcast_365_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 355.9 MiB)
# 24/03/14 23:14:26 INFO BlockManagerInfo: Added broadcast_365_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 365.4 MiB)
# 24/03/14 23:14:26 INFO SparkContext: Created broadcast 365 from textFile at <unknown>:0
# 24/03/14 23:14:26 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:26 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:26 INFO DAGScheduler: Got job 191 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:26 INFO DAGScheduler: Final stage: ResultStage 197 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:26 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:26 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:26 INFO DAGScheduler: Submitting ResultStage 197 (PythonRDD[584] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:26 INFO MemoryStore: Block broadcast_366 stored as values in memory (estimated size 7.7 KiB, free 355.9 MiB)
# 24/03/14 23:14:26 INFO MemoryStore: Block broadcast_366_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 355.9 MiB)
# 24/03/14 23:14:26 INFO BlockManagerInfo: Added broadcast_366_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 365.4 MiB)
# 24/03/14 23:14:26 INFO SparkContext: Created broadcast 366 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:26 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 197 (PythonRDD[584] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:26 INFO YarnScheduler: Adding task set 197.0 with 2 tasks resource profile 0
# 24/03/14 23:14:26 INFO TaskSetManager: Starting task 0.0 in stage 197.0 (TID 369) (worker-node-2, executor 2, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:26 INFO TaskSetManager: Starting task 1.0 in stage 197.0 (TID 370) (worker-node-1, executor 1, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:26 INFO BlockManagerInfo: Added broadcast_366_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 365.5 MiB)
# 24/03/14 23:14:26 INFO BlockManagerInfo: Added broadcast_366_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 365.4 MiB)
# 24/03/14 23:14:26 INFO BlockManagerInfo: Added broadcast_365_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 365.4 MiB)
# 24/03/14 23:14:26 INFO BlockManagerInfo: Added broadcast_365_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 365.4 MiB)
# 24/03/14 23:14:26 INFO TaskSetManager: Finished task 1.0 in stage 197.0 (TID 370) in 35 ms on worker-node-1 (executor 1) (1/2)
# 24/03/14 23:14:26 INFO TaskSetManager: Finished task 0.0 in stage 197.0 (TID 369) in 74 ms on worker-node-2 (executor 2) (2/2)
# 24/03/14 23:14:26 INFO YarnScheduler: Removed TaskSet 197.0, whose tasks have all completed, from pool
# 24/03/14 23:14:26 INFO DAGScheduler: ResultStage 197 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.083 s
# 24/03/14 23:14:26 INFO DAGScheduler: Job 191 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:26 INFO YarnScheduler: Killing all running tasks in stage 197: Stage finished
# 24/03/14 23:14:26 INFO DAGScheduler: Job 191 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.088909 s
# 24/03/14 23:14:26 INFO MemoryStore: Block broadcast_367 stored as values in memory (estimated size 358.7 KiB, free 355.6 MiB)
# 24/03/14 23:14:26 INFO MemoryStore: Block broadcast_367_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 355.5 MiB)
# 24/03/14 23:14:26 INFO BlockManagerInfo: Added broadcast_367_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 365.4 MiB)
# 24/03/14 23:14:26 INFO SparkContext: Created broadcast 367 from textFile at <unknown>:0
# 24/03/14 23:14:26 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:26 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:26 INFO DAGScheduler: Got job 192 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:26 INFO DAGScheduler: Final stage: ResultStage 198 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:26 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:26 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:26 INFO DAGScheduler: Submitting ResultStage 198 (PythonRDD[587] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:26 INFO MemoryStore: Block broadcast_368 stored as values in memory (estimated size 7.7 KiB, free 355.5 MiB)
# 24/03/14 23:14:26 INFO MemoryStore: Block broadcast_368_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 355.5 MiB)
# 24/03/14 23:14:26 INFO BlockManagerInfo: Added broadcast_368_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 365.4 MiB)
# 24/03/14 23:14:26 INFO SparkContext: Created broadcast 368 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:26 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 198 (PythonRDD[587] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# ...
# 24/03/14 23:14:53 INFO TaskSetManager: Starting task 1.0 in stage 381.0 (TID 738) (worker-node-2, executor 2, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_734_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 364.8 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_734_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 364.8 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_733_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 364.8 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_733_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 364.8 MiB)
# 24/03/14 23:14:53 INFO TaskSetManager: Finished task 1.0 in stage 381.0 (TID 738) in 35 ms on worker-node-2 (executor 2) (1/2)
# 24/03/14 23:14:53 INFO TaskSetManager: Finished task 0.0 in stage 381.0 (TID 737) in 72 ms on worker-node-1 (executor 1) (2/2)
# 24/03/14 23:14:53 INFO YarnScheduler: Removed TaskSet 381.0, whose tasks have all completed, from pool
# 24/03/14 23:14:53 INFO DAGScheduler: ResultStage 381 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.078 s
# 24/03/14 23:14:53 INFO DAGScheduler: Job 375 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:53 INFO YarnScheduler: Killing all running tasks in stage 381: Stage finished
# 24/03/14 23:14:53 INFO DAGScheduler: Job 375 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.083225 s
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_735 stored as values in memory (estimated size 358.7 KiB, free 348.3 MiB)
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_735_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 348.2 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_735_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO SparkContext: Created broadcast 735 from textFile at <unknown>:0
# 24/03/14 23:14:53 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:53 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:53 INFO DAGScheduler: Got job 376 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:53 INFO DAGScheduler: Final stage: ResultStage 382 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:53 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:53 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:53 INFO DAGScheduler: Submitting ResultStage 382 (PythonRDD[1139] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_736 stored as values in memory (estimated size 7.7 KiB, free 348.2 MiB)
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_736_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 348.2 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_736_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO SparkContext: Created broadcast 736 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:53 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 382 (PythonRDD[1139] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:53 INFO YarnScheduler: Adding task set 382.0 with 2 tasks resource profile 0
# 24/03/14 23:14:53 INFO TaskSetManager: Starting task 0.0 in stage 382.0 (TID 739) (worker-node-1, executor 1, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:53 INFO TaskSetManager: Starting task 1.0 in stage 382.0 (TID 740) (worker-node-2, executor 2, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_736_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 364.8 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_736_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 364.8 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_735_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 364.8 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_735_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO TaskSetManager: Finished task 1.0 in stage 382.0 (TID 740) in 41 ms on worker-node-2 (executor 2) (1/2)
# 24/03/14 23:14:53 INFO TaskSetManager: Finished task 0.0 in stage 382.0 (TID 739) in 60 ms on worker-node-1 (executor 1) (2/2)
# 24/03/14 23:14:53 INFO YarnScheduler: Removed TaskSet 382.0, whose tasks have all completed, from pool
# 24/03/14 23:14:53 INFO DAGScheduler: ResultStage 382 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.066 s
# 24/03/14 23:14:53 INFO DAGScheduler: Job 376 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:53 INFO YarnScheduler: Killing all running tasks in stage 382: Stage finished
# 24/03/14 23:14:53 INFO DAGScheduler: Job 376 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.067808 s
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_737 stored as values in memory (estimated size 358.7 KiB, free 347.9 MiB)
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_737_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 347.9 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_737_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO SparkContext: Created broadcast 737 from textFile at <unknown>:0
# 24/03/14 23:14:53 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:53 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:53 INFO DAGScheduler: Got job 377 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:53 INFO DAGScheduler: Final stage: ResultStage 383 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:53 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:53 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:53 INFO DAGScheduler: Submitting ResultStage 383 (PythonRDD[1142] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_738 stored as values in memory (estimated size 7.7 KiB, free 347.8 MiB)
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_738_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 347.8 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_738_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO SparkContext: Created broadcast 738 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:53 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 383 (PythonRDD[1142] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:53 INFO YarnScheduler: Adding task set 383.0 with 2 tasks resource profile 0
# 24/03/14 23:14:53 INFO TaskSetManager: Starting task 0.0 in stage 383.0 (TID 741) (worker-node-2, executor 2, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:53 INFO TaskSetManager: Starting task 1.0 in stage 383.0 (TID 742) (worker-node-1, executor 1, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_738_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 364.8 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_738_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_737_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_737_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO TaskSetManager: Finished task 0.0 in stage 383.0 (TID 741) in 67 ms on worker-node-2 (executor 2) (1/2)
# 24/03/14 23:14:53 INFO TaskSetManager: Finished task 1.0 in stage 383.0 (TID 742) in 96 ms on worker-node-1 (executor 1) (2/2)
# 24/03/14 23:14:53 INFO YarnScheduler: Removed TaskSet 383.0, whose tasks have all completed, from pool
# 24/03/14 23:14:53 INFO DAGScheduler: ResultStage 383 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.103 s
# 24/03/14 23:14:53 INFO DAGScheduler: Job 377 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:53 INFO YarnScheduler: Killing all running tasks in stage 383: Stage finished
# 24/03/14 23:14:53 INFO DAGScheduler: Job 377 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.108438 s
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_739 stored as values in memory (estimated size 358.7 KiB, free 347.5 MiB)
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_739_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 347.5 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_739_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO SparkContext: Created broadcast 739 from textFile at <unknown>:0
# 24/03/14 23:14:53 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:53 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:53 INFO DAGScheduler: Got job 378 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:53 INFO DAGScheduler: Final stage: ResultStage 384 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:53 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:53 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:53 INFO DAGScheduler: Submitting ResultStage 384 (PythonRDD[1145] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_740 stored as values in memory (estimated size 7.7 KiB, free 347.5 MiB)
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_740_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 347.4 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_740_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO SparkContext: Created broadcast 740 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:53 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 384 (PythonRDD[1145] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:53 INFO YarnScheduler: Adding task set 384.0 with 2 tasks resource profile 0
# 24/03/14 23:14:53 INFO TaskSetManager: Starting task 0.0 in stage 384.0 (TID 743) (worker-node-2, executor 2, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:53 INFO TaskSetManager: Starting task 1.0 in stage 384.0 (TID 744) (worker-node-1, executor 1, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_740_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_740_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_739_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_739_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO TaskSetManager: Finished task 0.0 in stage 384.0 (TID 743) in 32 ms on worker-node-2 (executor 2) (1/2)
# 24/03/14 23:14:53 INFO TaskSetManager: Finished task 1.0 in stage 384.0 (TID 744) in 191 ms on worker-node-1 (executor 1) (2/2)
# 24/03/14 23:14:53 INFO YarnScheduler: Removed TaskSet 384.0, whose tasks have all completed, from pool
# 24/03/14 23:14:53 INFO DAGScheduler: ResultStage 384 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.196 s
# 24/03/14 23:14:53 INFO DAGScheduler: Job 378 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:53 INFO YarnScheduler: Killing all running tasks in stage 384: Stage finished
# 24/03/14 23:14:53 INFO DAGScheduler: Job 378 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.199056 s
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_741 stored as values in memory (estimated size 358.7 KiB, free 347.1 MiB)
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_741_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 347.1 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_741_piece0 in memory on master-node:44443 (size: 33.1 KiB, free: 364.6 MiB)
# 24/03/14 23:14:53 INFO SparkContext: Created broadcast 741 from textFile at <unknown>:0
# 24/03/14 23:14:53 INFO FileInputFormat: Total input files to process : 1
# 24/03/14 23:14:53 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/2387453974.py:6
# 24/03/14 23:14:53 INFO DAGScheduler: Got job 379 (collect at /tmp/ipykernel_226860/2387453974.py:6) with 2 output partitions
# 24/03/14 23:14:53 INFO DAGScheduler: Final stage: ResultStage 385 (collect at /tmp/ipykernel_226860/2387453974.py:6)
# 24/03/14 23:14:53 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:14:53 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:14:53 INFO DAGScheduler: Submitting ResultStage 385 (PythonRDD[1148] at collect at /tmp/ipykernel_226860/2387453974.py:6), which has no missing parents
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_742 stored as values in memory (estimated size 7.7 KiB, free 347.1 MiB)
# 24/03/14 23:14:53 INFO MemoryStore: Block broadcast_742_piece0 stored as bytes in memory (estimated size 4.7 KiB, free 347.1 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_742_piece0 in memory on master-node:44443 (size: 4.7 KiB, free: 364.6 MiB)
# 24/03/14 23:14:53 INFO SparkContext: Created broadcast 742 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:14:53 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 385 (PythonRDD[1148] at collect at /tmp/ipykernel_226860/2387453974.py:6) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:14:53 INFO YarnScheduler: Adding task set 385.0 with 2 tasks resource profile 0
# 24/03/14 23:14:53 INFO TaskSetManager: Starting task 0.0 in stage 385.0 (TID 745) (worker-node-1, executor 1, partition 0, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:53 INFO TaskSetManager: Starting task 1.0 in stage 385.0 (TID 746) (worker-node-2, executor 2, partition 1, NODE_LOCAL, 7710 bytes)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_742_piece0 in memory on worker-node-1:37441 (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:14:53 INFO BlockManagerInfo: Added broadcast_742_piece0 in memory on worker-node-2:35017 (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:14:54 INFO BlockManagerInfo: Added broadcast_741_piece0 in memory on worker-node-1:37441 (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:14:54 INFO BlockManagerInfo: Added broadcast_741_piece0 in memory on worker-node-2:35017 (size: 33.1 KiB, free: 364.6 MiB)
# 24/03/14 23:14:54 INFO TaskSetManager: Finished task 1.0 in stage 385.0 (TID 746) in 30 ms on worker-node-2 (executor 2) (1/2)
# 24/03/14 23:14:54 INFO TaskSetManager: Finished task 0.0 in stage 385.0 (TID 745) in 107 ms on worker-node-1 (executor 1) (2/2)
# 24/03/14 23:14:54 INFO YarnScheduler: Removed TaskSet 385.0, whose tasks have all completed, from pool
# 24/03/14 23:14:54 INFO DAGScheduler: ResultStage 385 (collect at /tmp/ipykernel_226860/2387453974.py:6) finished in 0.111 s
# 24/03/14 23:14:54 INFO DAGScheduler: Job 379 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:14:54 INFO YarnScheduler: Killing all running tasks in stage 385: Stage finished
# 24/03/14 23:14:54 INFO DAGScheduler: Job 379 finished: collect at /tmp/ipykernel_226860/2387453974.py:6, took 0.113406 s

# %%
# Erstelle DataFrame aus den gesammelten Zeilen
schema = sqlContext.createDataFrame(all_rows)

# Register the DataFrame as a table
schema.registerTempTable("combined_data_table")

# Zeige das Ergebnis
result = sqlContext.sql("SELECT * FROM combined_data_table")
result.show()
# Out:
# 24/03/14 23:20:23 INFO SparkContext: Starting job: showString at NativeMethodAccessorImpl.java:0
# 24/03/14 23:20:23 INFO DAGScheduler: Got job 380 (showString at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 24/03/14 23:20:23 INFO DAGScheduler: Final stage: ResultStage 386 (showString at NativeMethodAccessorImpl.java:0)
# 24/03/14 23:20:23 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:20:23 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:20:23 INFO DAGScheduler: Submitting ResultStage 386 (MapPartitionsRDD[1155] at showString at NativeMethodAccessorImpl.java:0), which has no missing parents
# 24/03/14 23:20:23 INFO MemoryStore: Block broadcast_743 stored as values in memory (estimated size 14.7 KiB, free 347.0 MiB)
# 24/03/14 23:20:23 INFO MemoryStore: Block broadcast_743_piece0 stored as bytes in memory (estimated size 7.0 KiB, free 347.0 MiB)
# 24/03/14 23:20:23 INFO BlockManagerInfo: Added broadcast_743_piece0 in memory on master-node:44443 (size: 7.0 KiB, free: 364.6 MiB)
# 24/03/14 23:20:23 INFO SparkContext: Created broadcast 743 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:20:23 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 386 (MapPartitionsRDD[1155] at showString at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 24/03/14 23:20:23 INFO YarnScheduler: Adding task set 386.0 with 1 tasks resource profile 0
# 24/03/14 23:20:23 INFO TaskSetManager: Starting task 0.0 in stage 386.0 (TID 747) (worker-node-1, executor 1, partition 0, PROCESS_LOCAL, 13411 bytes)
# 24/03/14 23:20:23 INFO BlockManagerInfo: Added broadcast_743_piece0 in memory on worker-node-1:37441 (size: 7.0 KiB, free: 364.7 MiB)
# +-------+-------+-------+-------+-------+-------+-------+-------+
# |column1|column2|column3|column4|column5|column6|column7|column8|
# +-------+-------+-------+-------+-------+-------+-------+-------+
# |218.932|  0.247|218.932|-11.197|      1| 92.198|      4|  0.778|
# |148.035|  0.148|137.915| -9.843|      6|121.274|      4|  0.384|
# |177.475|  0.282|172.304| -9.689|      8| 100.07|      1|      0|
# |233.404|      0|217.124| -9.013|      0|119.293|      4|      0|
# |209.606|  0.066|198.699| -4.501|      2|129.738|      4|  0.562|
# |267.702|  2.264| 254.27| -9.323|      5|147.782|      3|  0.454|
# |114.782|  0.096|114.782|-17.302|      1|111.787|      1|      0|
# | 189.57|  0.319|181.023|-11.642|      4| 101.43|      3|  0.408|
# |269.818|    5.3| 258.99|-13.496|      4| 86.643|      4|  0.487|
# |266.396|  0.084|261.747| -6.697|      7|114.041|      4|  0.878|
# |218.775|  2.125|207.012|-10.021|      5|146.765|      1|      0|
# |245.211|  0.357| 227.48| -7.545|      7|117.975|      4|  0.835|
# |226.351|      0|221.553| -6.632|      9| 130.04|      4|      0|
# |191.843|   0.38|188.424|  -7.75|     10|137.334|      1|  0.319|
# |307.382|  0.612|296.658| -8.346|      3|125.197|      3|  0.211|
# |491.128|      0|486.034| -8.576|      7|119.826|      4|  0.756|
# |228.597|  0.223|217.426| -16.11|      8|127.756|      5|  0.579|
# |599.249|  1.193|591.999| -8.032|      6| 99.273|      4|  0.158|
# |290.298|  0.145|285.605| -5.271|      7|150.062|      4|  0.931|
# |165.694|  0.162|157.391| -6.787|      7|138.331|      4|  0.127|
# +-------+-------+-------+-------+-------+-------+-------+-------+
# only showing top 20 rows
# 24/03/14 23:20:24 INFO TaskSetManager: Finished task 0.0 in stage 386.0 (TID 747) in 769 ms on worker-node-1 (executor 1) (1/1)
# 24/03/14 23:20:24 INFO YarnScheduler: Removed TaskSet 386.0, whose tasks have all completed, from pool
# 24/03/14 23:20:24 INFO DAGScheduler: ResultStage 386 (showString at NativeMethodAccessorImpl.java:0) finished in 0.777 s
# 24/03/14 23:20:24 INFO DAGScheduler: Job 380 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:20:24 INFO YarnScheduler: Killing all running tasks in stage 386: Stage finished
# 24/03/14 23:20:24 INFO DAGScheduler: Job 380 finished: showString at NativeMethodAccessorImpl.java:0, took 0.779313 s

# %%
schema = StructType([
    StructField("duration", True),
    StructField("end_of_fade_in", FloatType(), True),
    StructField("start_of_fade_out", FloatType(), True),
    StructField("loudness", FloatType(), True),
    StructField("key", FloatType(), True),
    StructField("tempo", FloatType(), True),
    StructField("time_signature", FloatType(), True),
    StructField("time_signature_confidence", FloatType(), True),
])

# %%
# Erstelle DataFrame aus den gesammelten Zeilen
df = sqlContext.createDataFrame(all_rows, schema)
# Out:
# ---------------------------------------------------------------------------
# PySparkTypeError                          Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Erstelle DataFrame aus den gesammelten Zeilen
# ----> 2 df = sqlContext.createDataFrame(all_rows, schema)
#
# File ~/.local/lib/python3.8/site-packages/pyspark/sql/context.py:486, in SQLContext.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     380 def createDataFrame(  # type: ignore[misc]
#     381     self,
#     382     data: Union[RDD[Any], Iterable[Any], "PandasDataFrameLike"],
#    (...)
#     385     verifySchema: bool = True,
#     386 ) -> DataFrame:
#     387     """
#     388     Creates a :class:`DataFrame` from an :class:`RDD`, a list or a :class:`pandas.DataFrame`.
#     389
#    (...)
#     484     Py4JJavaError: ...
#     485     """
# --> 486     return self.sparkSession.createDataFrame(  # type: ignore[call-overload]
#     487         data, schema, samplingRatio, verifySchema
#     488     )
#
# File ~/.local/lib/python3.8/site-packages/pyspark/sql/session.py:1443, in SparkSession.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#    1438 if has_pandas and isinstance(data, pd.DataFrame):
#    1439     # Create a DataFrame from pandas DataFrame.
#    1440     return super(SparkSession, self).createDataFrame(  # type: ignore[call-overload]
#    1441         data, schema, samplingRatio, verifySchema
#    1442     )
# -> 1443 return self._create_dataframe(
#    1444     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#    1445 )
#
# File ~/.local/lib/python3.8/site-packages/pyspark/sql/session.py:1485, in SparkSession._create_dataframe(self, data, schema, samplingRatio, verifySchema)
#    1483     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#    1484 else:
# -> 1485     rdd, struct = self._createFromLocal(map(prepare, data), schema)
#    1486 assert self._jvm is not None
#    1487 jrdd = self._jvm.SerDeUtil.toJavaArray(rdd._to_java_object_rdd())
#
# File ~/.local/lib/python3.8/site-packages/pyspark/sql/session.py:1090, in SparkSession._createFromLocal(self, data, schema)
#    1088 # make sure data could consumed multiple times
#    1089 if not isinstance(data, list):
# -> 1090     data = list(data)
#    1092 if schema is None or isinstance(schema, (list, tuple)):
#    1093     struct = self._inferSchemaFromList(data, names=schema)
#
# File ~/.local/lib/python3.8/site-packages/pyspark/sql/session.py:1459, in SparkSession._create_dataframe.<locals>.prepare(obj)
#    1457 @no_type_check
#    1458 def prepare(obj):
# -> 1459     verify_func(obj)
#    1460     return obj
#
# File ~/.local/lib/python3.8/site-packages/pyspark/sql/types.py:2187, in _make_type_verifier.<locals>.verify(obj)
#    2185 def verify(obj: Any) -> None:
#    2186     if not verify_nullability(obj):
# -> 2187         verify_value(obj)
#
# File ~/.local/lib/python3.8/site-packages/pyspark/sql/types.py:2160, in _make_type_verifier.<locals>.verify_struct(obj)
#    2150         raise PySparkValueError(
#    2151             error_class="LENGTH_SHOULD_BE_THE_SAME",
#    2152             message_parameters={
#    (...)
#    2157             },
#    2158         )
#    2159     for v, (_, verifier) in zip(obj, verifiers):
# -> 2160         verifier(v)
#    2161 elif hasattr(obj, "__dict__"):
#    2162     d = obj.__dict__
#
# File ~/.local/lib/python3.8/site-packages/pyspark/sql/types.py:2187, in _make_type_verifier.<locals>.verify(obj)
#    2185 def verify(obj: Any) -> None:
#    2186     if not verify_nullability(obj):
# -> 2187         verify_value(obj)
#
# File ~/.local/lib/python3.8/site-packages/pyspark/sql/types.py:2181, in _make_type_verifier.<locals>.verify_default(obj)
#    2179 def verify_default(obj: Any) -> None:
#    2180     assert_acceptable_types(obj)
# -> 2181     verify_acceptable_types(obj)
#
# File ~/.local/lib/python3.8/site-packages/pyspark/sql/types.py:2006, in _make_type_verifier.<locals>.verify_acceptable_types(obj)
#    2003 def verify_acceptable_types(obj: Any) -> None:
#    2004     # subclass of them can not be fromInternal in JVM
#    2005     if type(obj) not in _acceptable_types[_type]:
# -> 2006         raise PySparkTypeError(
#    2007             error_class="CANNOT_ACCEPT_OBJECT_IN_TYPE",
#    2008             message_parameters={
#    2009                 "data_type": str(dataType),
#    2010                 "obj_name": str(obj),
#    2011                 "obj_type": type(obj).__name__,
#    2012             },
#    2013         )
#
# PySparkTypeError: [CANNOT_ACCEPT_OBJECT_IN_TYPE] `FloatType()` can not accept object `218.932` in type `str`.

# %%
print("Number of rows in the DataFrame:", df.count())
# Out:
# Number of rows in the DataFrame: 200
# 24/03/14 23:20:34 INFO DAGScheduler: Registering RDD 1162 (count at NativeMethodAccessorImpl.java:0) as input to shuffle 6
# 24/03/14 23:20:34 INFO DAGScheduler: Got map stage job 381 (count at NativeMethodAccessorImpl.java:0) with 2 output partitions
# 24/03/14 23:20:34 INFO DAGScheduler: Final stage: ShuffleMapStage 387 (count at NativeMethodAccessorImpl.java:0)
# 24/03/14 23:20:34 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:20:34 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:20:34 INFO DAGScheduler: Submitting ShuffleMapStage 387 (MapPartitionsRDD[1162] at count at NativeMethodAccessorImpl.java:0), which has no missing parents
# 24/03/14 23:20:34 INFO MemoryStore: Block broadcast_744 stored as values in memory (estimated size 16.1 KiB, free 347.0 MiB)
# 24/03/14 23:20:34 INFO MemoryStore: Block broadcast_744_piece0 stored as bytes in memory (estimated size 8.3 KiB, free 347.0 MiB)
# 24/03/14 23:20:34 INFO BlockManagerInfo: Added broadcast_744_piece0 in memory on master-node:44443 (size: 8.3 KiB, free: 364.6 MiB)
# 24/03/14 23:20:34 INFO SparkContext: Created broadcast 744 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:20:34 INFO DAGScheduler: Submitting 2 missing tasks from ShuffleMapStage 387 (MapPartitionsRDD[1162] at count at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:20:34 INFO YarnScheduler: Adding task set 387.0 with 2 tasks resource profile 0
# 24/03/14 23:20:34 INFO TaskSetManager: Starting task 0.0 in stage 387.0 (TID 748) (worker-node-2, executor 2, partition 0, PROCESS_LOCAL, 13400 bytes)
# 24/03/14 23:20:34 INFO TaskSetManager: Starting task 1.0 in stage 387.0 (TID 749) (worker-node-1, executor 1, partition 1, PROCESS_LOCAL, 13422 bytes)
# 24/03/14 23:20:34 INFO BlockManagerInfo: Added broadcast_744_piece0 in memory on worker-node-1:37441 (size: 8.3 KiB, free: 364.7 MiB)
# 24/03/14 23:20:34 INFO BlockManagerInfo: Added broadcast_744_piece0 in memory on worker-node-2:35017 (size: 8.3 KiB, free: 364.6 MiB)
# 24/03/14 23:20:34 INFO TaskSetManager: Finished task 1.0 in stage 387.0 (TID 749) in 37 ms on worker-node-1 (executor 1) (1/2)
# 24/03/14 23:20:34 INFO TaskSetManager: Finished task 0.0 in stage 387.0 (TID 748) in 59 ms on worker-node-2 (executor 2) (2/2)
# 24/03/14 23:20:34 INFO YarnScheduler: Removed TaskSet 387.0, whose tasks have all completed, from pool
# 24/03/14 23:20:34 INFO DAGScheduler: ShuffleMapStage 387 (count at NativeMethodAccessorImpl.java:0) finished in 0.067 s
# 24/03/14 23:20:34 INFO DAGScheduler: looking for newly runnable stages
# 24/03/14 23:20:34 INFO DAGScheduler: running: Set()
# 24/03/14 23:20:34 INFO DAGScheduler: waiting: Set()
# 24/03/14 23:20:34 INFO DAGScheduler: failed: Set()
# 24/03/14 23:20:34 INFO SparkContext: Starting job: count at NativeMethodAccessorImpl.java:0
# 24/03/14 23:20:34 INFO DAGScheduler: Got job 382 (count at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 24/03/14 23:20:34 INFO DAGScheduler: Final stage: ResultStage 389 (count at NativeMethodAccessorImpl.java:0)
# 24/03/14 23:20:34 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 388)
# 24/03/14 23:20:34 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:20:34 INFO DAGScheduler: Submitting ResultStage 389 (MapPartitionsRDD[1165] at count at NativeMethodAccessorImpl.java:0), which has no missing parents
# 24/03/14 23:20:34 INFO MemoryStore: Block broadcast_745 stored as values in memory (estimated size 12.5 KiB, free 347.0 MiB)
# 24/03/14 23:20:34 INFO MemoryStore: Block broadcast_745_piece0 stored as bytes in memory (estimated size 5.9 KiB, free 347.0 MiB)
# 24/03/14 23:20:34 INFO BlockManagerInfo: Added broadcast_745_piece0 in memory on master-node:44443 (size: 5.9 KiB, free: 364.6 MiB)
# 24/03/14 23:20:34 INFO SparkContext: Created broadcast 745 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:20:34 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 389 (MapPartitionsRDD[1165] at count at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 24/03/14 23:20:34 INFO YarnScheduler: Adding task set 389.0 with 1 tasks resource profile 0
# 24/03/14 23:20:34 INFO TaskSetManager: Starting task 0.0 in stage 389.0 (TID 750) (worker-node-1, executor 1, partition 0, NODE_LOCAL, 7626 bytes)
# 24/03/14 23:20:34 INFO BlockManagerInfo: Added broadcast_745_piece0 in memory on worker-node-1:37441 (size: 5.9 KiB, free: 364.6 MiB)
# 24/03/14 23:20:34 INFO MapOutputTrackerMasterEndpoint: Asked to send map output locations for shuffle 6 to 192.168.2.124:60916
# 24/03/14 23:20:34 INFO TaskSetManager: Finished task 0.0 in stage 389.0 (TID 750) in 25 ms on worker-node-1 (executor 1) (1/1)
# 24/03/14 23:20:34 INFO YarnScheduler: Removed TaskSet 389.0, whose tasks have all completed, from pool
# 24/03/14 23:20:34 INFO DAGScheduler: ResultStage 389 (count at NativeMethodAccessorImpl.java:0) finished in 0.031 s
# 24/03/14 23:20:34 INFO DAGScheduler: Job 382 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:20:34 INFO YarnScheduler: Killing all running tasks in stage 389: Stage finished
# 24/03/14 23:20:34 INFO DAGScheduler: Job 382 finished: count at NativeMethodAccessorImpl.java:0, took 0.033571 s

# %%
df.show()
# Out:
# +-------+-------+-------+-------+-------+-------+-------+-------+
# |column1|column2|column3|column4|column5|column6|column7|column8|
# +-------+-------+-------+-------+-------+-------+-------+-------+
# |218.932|  0.247|218.932|-11.197|      1| 92.198|      4|  0.778|
# |148.035|  0.148|137.915| -9.843|      6|121.274|      4|  0.384|
# |177.475|  0.282|172.304| -9.689|      8| 100.07|      1|      0|
# |233.404|      0|217.124| -9.013|      0|119.293|      4|      0|
# |209.606|  0.066|198.699| -4.501|      2|129.738|      4|  0.562|
# |267.702|  2.264| 254.27| -9.323|      5|147.782|      3|  0.454|
# |114.782|  0.096|114.782|-17.302|      1|111.787|      1|      0|
# | 189.57|  0.319|181.023|-11.642|      4| 101.43|      3|  0.408|
# |269.818|    5.3| 258.99|-13.496|      4| 86.643|      4|  0.487|
# |266.396|  0.084|261.747| -6.697|      7|114.041|      4|  0.878|
# |218.775|  2.125|207.012|-10.021|      5|146.765|      1|      0|
# |245.211|  0.357| 227.48| -7.545|      7|117.975|      4|  0.835|
# |226.351|      0|221.553| -6.632|      9| 130.04|      4|      0|
# |191.843|   0.38|188.424|  -7.75|     10|137.334|      1|  0.319|
# |307.382|  0.612|296.658| -8.346|      3|125.197|      3|  0.211|
# |491.128|      0|486.034| -8.576|      7|119.826|      4|  0.756|
# |228.597|  0.223|217.426| -16.11|      8|127.756|      5|  0.579|
# |599.249|  1.193|591.999| -8.032|      6| 99.273|      4|  0.158|
# |290.298|  0.145|285.605| -5.271|      7|150.062|      4|  0.931|
# |165.694|  0.162|157.391| -6.787|      7|138.331|      4|  0.127|
# +-------+-------+-------+-------+-------+-------+-------+-------+
# only showing top 20 rows
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_730_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 364.6 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_730_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 364.6 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_730_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 364.6 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_733_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 364.6 MiB)
# 24/03/14 23:20:37 INFO SparkContext: Starting job: showString at NativeMethodAccessorImpl.java:0
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_733_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_733_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO DAGScheduler: Got job 383 (showString at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 24/03/14 23:20:37 INFO DAGScheduler: Final stage: ResultStage 390 (showString at NativeMethodAccessorImpl.java:0)
# 24/03/14 23:20:37 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:20:37 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:20:37 INFO DAGScheduler: Submitting ResultStage 390 (MapPartitionsRDD[1167] at showString at NativeMethodAccessorImpl.java:0), which has no missing parents
# 24/03/14 23:20:37 INFO MemoryStore: Block broadcast_746 stored as values in memory (estimated size 14.7 KiB, free 347.4 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_724_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_724_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_724_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO MemoryStore: Block broadcast_746_piece0 stored as bytes in memory (estimated size 7.0 KiB, free 347.4 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Added broadcast_746_piece0 in memory on master-node:44443 (size: 7.0 KiB, free: 364.6 MiB)
# 24/03/14 23:20:37 INFO SparkContext: Created broadcast 746 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:20:37 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 390 (MapPartitionsRDD[1167] at showString at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 24/03/14 23:20:37 INFO YarnScheduler: Adding task set 390.0 with 1 tasks resource profile 0
# 24/03/14 23:20:37 INFO TaskSetManager: Starting task 0.0 in stage 390.0 (TID 751) (worker-node-1, executor 1, partition 0, PROCESS_LOCAL, 13411 bytes)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_731_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_731_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_731_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Added broadcast_746_piece0 in memory on worker-node-1:37441 (size: 7.0 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_729_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_729_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_729_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_738_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_738_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_738_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO TaskSetManager: Finished task 0.0 in stage 390.0 (TID 751) in 18 ms on worker-node-1 (executor 1) (1/1)
# 24/03/14 23:20:37 INFO YarnScheduler: Removed TaskSet 390.0, whose tasks have all completed, from pool
# 24/03/14 23:20:37 INFO DAGScheduler: ResultStage 390 (showString at NativeMethodAccessorImpl.java:0) finished in 0.024 s
# 24/03/14 23:20:37 INFO DAGScheduler: Job 383 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:20:37 INFO YarnScheduler: Killing all running tasks in stage 390: Stage finished
# 24/03/14 23:20:37 INFO DAGScheduler: Job 383 finished: showString at NativeMethodAccessorImpl.java:0, took 0.026688 s
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_722_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_722_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 364.8 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_722_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 364.7 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_715_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 364.8 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_715_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 364.8 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_715_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 364.8 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_707_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 364.8 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_707_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 364.8 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_707_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 364.8 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_719_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 364.8 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_719_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 364.9 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_719_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 364.8 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_726_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 364.8 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_726_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 364.9 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_726_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 364.8 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_734_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 364.8 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_734_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 364.9 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_734_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 364.8 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_725_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 364.9 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_725_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 364.9 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_725_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 364.9 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_723_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 364.9 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_723_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 364.9 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_723_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 364.9 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_727_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 364.9 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_727_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_727_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 364.9 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_735_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_735_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_735_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_711_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_711_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_711_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_728_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_728_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_728_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_732_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_732_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_732_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_744_piece0 on master-node:44443 in memory (size: 8.3 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_744_piece0 on worker-node-2:35017 in memory (size: 8.3 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_744_piece0 on worker-node-1:37441 in memory (size: 8.3 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_717_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_717_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_717_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_743_piece0 on master-node:44443 in memory (size: 7.0 KiB, free: 365.0 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_743_piece0 on worker-node-1:37441 in memory (size: 7.0 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_745_piece0 on master-node:44443 in memory (size: 5.9 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_745_piece0 on worker-node-1:37441 in memory (size: 5.9 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_709_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_709_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_709_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_736_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_736_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_736_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_713_piece0 on worker-node-2:35017 in memory (size: 33.1 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_713_piece0 on worker-node-1:37441 in memory (size: 33.1 KiB, free: 365.2 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_713_piece0 on master-node:44443 in memory (size: 33.1 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_742_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_742_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_742_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 365.2 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_740_piece0 on master-node:44443 in memory (size: 4.7 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_740_piece0 on worker-node-2:35017 in memory (size: 4.7 KiB, free: 365.1 MiB)
# 24/03/14 23:20:37 INFO BlockManagerInfo: Removed broadcast_740_piece0 on worker-node-1:37441 in memory (size: 4.7 KiB, free: 365.2 MiB)

# %%
# Führe die angegebene Abfrage aus, um durchschnittliche Werte zu berechnen
average_values = df.agg({'column1': 'avg', 'column2': 'avg', 'column3': 'avg', 'column4': 'avg', 'column5': 'avg', 'column6': 'avg', 'column7': 'avg', 'column8': 'avg'}).collect()[0]
print("Durchschnittswerte:")
for col_name, avg_value in average_values.asDict().items():
    print(f"{col_name}: {avg_value}")
# Out:
# Durchschnittswerte:
# avg(column3): 230.37028000000007
# avg(column1): 239.11645049999998
# avg(column6): 127.39284500000002
# avg(column2): 0.8018450000000003
# avg(column7): 3.415
# avg(column5): 5.445
# avg(column4): -10.243735000000001
# avg(column8): 0.5016700000000001
# 24/03/14 23:20:41 INFO DAGScheduler: Registering RDD 1169 (collect at /tmp/ipykernel_226860/960308202.py:2) as input to shuffle 7
# 24/03/14 23:20:41 INFO DAGScheduler: Got map stage job 384 (collect at /tmp/ipykernel_226860/960308202.py:2) with 2 output partitions
# 24/03/14 23:20:41 INFO DAGScheduler: Final stage: ShuffleMapStage 391 (collect at /tmp/ipykernel_226860/960308202.py:2)
# 24/03/14 23:20:41 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 23:20:41 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:20:41 INFO DAGScheduler: Submitting ShuffleMapStage 391 (MapPartitionsRDD[1169] at collect at /tmp/ipykernel_226860/960308202.py:2), which has no missing parents
# 24/03/14 23:20:41 INFO MemoryStore: Block broadcast_747 stored as values in memory (estimated size 40.0 KiB, free 352.5 MiB)
# 24/03/14 23:20:41 INFO MemoryStore: Block broadcast_747_piece0 stored as bytes in memory (estimated size 14.7 KiB, free 352.5 MiB)
# 24/03/14 23:20:41 INFO BlockManagerInfo: Added broadcast_747_piece0 in memory on master-node:44443 (size: 14.7 KiB, free: 365.1 MiB)
# 24/03/14 23:20:41 INFO SparkContext: Created broadcast 747 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:20:41 INFO DAGScheduler: Submitting 2 missing tasks from ShuffleMapStage 391 (MapPartitionsRDD[1169] at collect at /tmp/ipykernel_226860/960308202.py:2) (first 15 tasks are for partitions Vector(0, 1))
# 24/03/14 23:20:41 INFO YarnScheduler: Adding task set 391.0 with 2 tasks resource profile 0
# 24/03/14 23:20:41 INFO TaskSetManager: Starting task 0.0 in stage 391.0 (TID 752) (worker-node-1, executor 1, partition 0, PROCESS_LOCAL, 13400 bytes)
# 24/03/14 23:20:41 INFO TaskSetManager: Starting task 1.0 in stage 391.0 (TID 753) (worker-node-2, executor 2, partition 1, PROCESS_LOCAL, 13422 bytes)
# 24/03/14 23:20:41 INFO BlockManagerInfo: Added broadcast_747_piece0 in memory on worker-node-2:35017 (size: 14.7 KiB, free: 365.1 MiB)
# 24/03/14 23:20:41 INFO BlockManagerInfo: Added broadcast_747_piece0 in memory on worker-node-1:37441 (size: 14.7 KiB, free: 365.1 MiB)
# 24/03/14 23:20:41 INFO TaskSetManager: Finished task 1.0 in stage 391.0 (TID 753) in 21 ms on worker-node-2 (executor 2) (1/2)
# 24/03/14 23:20:41 INFO TaskSetManager: Finished task 0.0 in stage 391.0 (TID 752) in 30 ms on worker-node-1 (executor 1) (2/2)
# 24/03/14 23:20:41 INFO YarnScheduler: Removed TaskSet 391.0, whose tasks have all completed, from pool
# 24/03/14 23:20:41 INFO DAGScheduler: ShuffleMapStage 391 (collect at /tmp/ipykernel_226860/960308202.py:2) finished in 0.043 s
# 24/03/14 23:20:41 INFO DAGScheduler: looking for newly runnable stages
# 24/03/14 23:20:41 INFO DAGScheduler: running: Set()
# 24/03/14 23:20:41 INFO DAGScheduler: waiting: Set()
# 24/03/14 23:20:41 INFO DAGScheduler: failed: Set()
# 24/03/14 23:20:41 INFO SparkContext: Starting job: collect at /tmp/ipykernel_226860/960308202.py:2
# 24/03/14 23:20:41 INFO DAGScheduler: Got job 385 (collect at /tmp/ipykernel_226860/960308202.py:2) with 1 output partitions
# 24/03/14 23:20:41 INFO DAGScheduler: Final stage: ResultStage 393 (collect at /tmp/ipykernel_226860/960308202.py:2)
# 24/03/14 23:20:41 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 392)
# 24/03/14 23:20:41 INFO DAGScheduler: Missing parents: List()
# 24/03/14 23:20:41 INFO DAGScheduler: Submitting ResultStage 393 (MapPartitionsRDD[1172] at collect at /tmp/ipykernel_226860/960308202.py:2), which has no missing parents
# 24/03/14 23:20:41 INFO MemoryStore: Block broadcast_748 stored as values in memory (estimated size 30.4 KiB, free 352.4 MiB)
# 24/03/14 23:20:41 INFO MemoryStore: Block broadcast_748_piece0 stored as bytes in memory (estimated size 10.4 KiB, free 352.4 MiB)
# 24/03/14 23:20:41 INFO BlockManagerInfo: Added broadcast_748_piece0 in memory on master-node:44443 (size: 10.4 KiB, free: 365.1 MiB)
# 24/03/14 23:20:41 INFO SparkContext: Created broadcast 748 from broadcast at DAGScheduler.scala:1585
# 24/03/14 23:20:41 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 393 (MapPartitionsRDD[1172] at collect at /tmp/ipykernel_226860/960308202.py:2) (first 15 tasks are for partitions Vector(0))
# 24/03/14 23:20:41 INFO YarnScheduler: Adding task set 393.0 with 1 tasks resource profile 0
# 24/03/14 23:20:41 INFO TaskSetManager: Starting task 0.0 in stage 393.0 (TID 754) (worker-node-1, executor 1, partition 0, NODE_LOCAL, 7626 bytes)
# 24/03/14 23:20:41 INFO BlockManagerInfo: Added broadcast_748_piece0 in memory on worker-node-1:37441 (size: 10.4 KiB, free: 365.1 MiB)
# 24/03/14 23:20:41 INFO MapOutputTrackerMasterEndpoint: Asked to send map output locations for shuffle 7 to 192.168.2.124:60916
# 24/03/14 23:20:42 INFO TaskSetManager: Finished task 0.0 in stage 393.0 (TID 754) in 91 ms on worker-node-1 (executor 1) (1/1)
# 24/03/14 23:20:42 INFO YarnScheduler: Removed TaskSet 393.0, whose tasks have all completed, from pool
# 24/03/14 23:20:42 INFO DAGScheduler: ResultStage 393 (collect at /tmp/ipykernel_226860/960308202.py:2) finished in 0.098 s
# 24/03/14 23:20:42 INFO DAGScheduler: Job 385 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 23:20:42 INFO YarnScheduler: Killing all running tasks in stage 393: Stage finished
# 24/03/14 23:20:42 INFO DAGScheduler: Job 385 finished: collect at /tmp/ipykernel_226860/960308202.py:2, took 0.102913 s

# %%
rdd = spark_context.textFile('hdfs://master-node:9000/user/hadoop/MillionSongSubset_ASCI_analysis_songs/TRAAAAW128F429D538_songs.asci')

# %%
rdd = rdd.map(lambda line: line.strip('{}').split(','))

# %%
rdd = rdd.map(lambda row: [str(elem) for elem in row])

# %%
df = rdd.toDF()

# %%
df.show()

# %% [markdown]
# # 3) H5Py file object file creation from the H5 file

# %% [markdown]
# # Debug: Only one h5File

# %%
h5_file_paths = ['hdfs://master-node:9000/user/hadoop/MillionSongSubset/A/A/A/TRAAAAW128F429D538.h5']
h5_file_path = 'hdfs://master-node:9000/user/hadoop/MillionSongSubset/A/A/A/TRAAAAW128F429D538.h5'

# %% [markdown]
# # Version 1

# %%
def extract_info(file_path):
    with h5py.File(file_path, 'r') as file:
        song = file['analysis']['songs']
        np_song = np.array(song[0])
        selected_features = np_song[['danceability', 'duration', 'tempo', 'energy', 'loudness']].ravel()
        return selected_features.tolist()
        #print(f"File found: {file_path}")
         #return file_path
    # except FileNotFoundError:
    #     print(f"File not found: {file_path}")
    #     return None

# %%
file_paths = spark_context.parallelize(h5_file_path)
files_infos_rdd = file_paths.map(extract_info)

# %%
print(files_infos_rdd.collect())

# %% [markdown]
# # 4) Create Spark Data Frame

# %%
# Definiere das Schema für den DataFrame
schema = StructType([
    StructField("danceability", FloatType(), True),
    StructField("duration", FloatType(), True),
    StructField("tempo", FloatType(), True),
    StructField("energy", FloatType(), True),
    StructField("loudness", FloatType(), True),
])

# %%
spark_df = sqlContext.createDataFrame(files_infos_rdd.flatMap(lambda x: x), schema=schema)

# %%
# Zeige den DataFrame-Inhalt
spark_df.show()

# %% [markdown]
# # Calculation (Average)

# %%
average_values = spark_df.agg({'danceability': 'avg', 'duration': 'avg', 'tempo': 'avg', 'energy': 'avg', 'loudness': 'avg'}).collect()[0]
print("Average Values::")
for col_name, avg_value in average_values.asDict().items():
    print(f"{col_name}: {avg_value}")

# %% [markdown]
# # STOP SPARK

# %%
# release the cores
spark_context.stop()
